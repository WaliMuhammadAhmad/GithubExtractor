# %% [markdown]
# <a href="https://colab.research.google.com/github/WaliMuhammadAhmad/CODEX-Dataset/blob/main/Eval4Deepseek_Coder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tarfile
import logging
import shutil
import json
import os

# %%
from google.colab import userdata
from huggingface_hub import login
from huggingface_hub import Repository
from huggingface_hub import create_repo

# %% [markdown]
# ### Define Global Variables

# %%
folder = 'eval'  # this name will be use in all notebook
files = 0     # count the number of files
count = 1     # count for the folders
files_per_folder = 10000  # files per folder. hugging face repo uses Git LFS by default but still make issue for more then 10k files in a folder
context_type = "FM_FC_MS_FF"  # Choose context type from: FM, FM_FC, FM_FC_CO, FM_FC_MS, FM_FC_MS_FF

# Path
file = f'/content/drive/MyDrive/Colab Notebooks/Dataset/{folder}.tar.bz2'
input_path = f'/content/{folder}/'
output_path = '/content/Eval4Deepseek-Coder'

# %% [markdown]
# ### Define Functions

# %%
def preprocess_dataset(input_folder, output_folder, context_type):
    contexts = {
        "FM": "src_fm",
        "FM_FC": "src_fm_fc",
        "FM_FC_CO": "src_fm_fc_co",
        "FM_FC_MS": "src_fm_fc_ms",
        "FM_FC_MS_FF": "src_fm_fc_ms_ff"
    }

    if context_type not in contexts:
        raise ValueError("Invalid context type. Choose from: FM, FM_FC, FM_FC_CO, FM_FC_MS, FM_FC_MS_FF.")

    context_key = contexts[context_type]

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for subdir, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith('_corpus.json'):
                input_path = os.path.join(subdir, file)
                try:
                    with open(input_path, 'r') as infile:
                        data = json.load(infile)

                        if context_key in data and 'target' in data:
                            instruction = (f"Generate a unit test case for the following Java method: {data[context_key]}")
                            output = (f"The unit test case for the given Java method is: {data['target']}")
                            transform_data = {
                                'instruction': instruction,
                                'output': output
                            }

                            # Determine the output path
                            relative_path = os.path.relpath(input_path, input_folder)
                            output_path = os.path.join(output_folder, relative_path)

                            # Ensure the output directory exists
                            os.makedirs(os.path.dirname(output_path), exist_ok=True)

                            # Write the transformed data to the output path
                            with open(output_path, 'w') as outfile:
                                json.dump(transform_data, outfile, indent=4)
                except Exception as e:
                    logger.error(f"Error processing file {input_path}: {e}")

print(f"Preprocessing complete on {input_path} @ {output_path}")
# Out:
# Preprocessing complete on /content/eval/ @ /content/Eval4Deepseek-Coder

# %%
def count_files(directory=dir):
  try:
      entries = os.listdir(directory)
      files = [entry for entry in entries if os.path.isfile(os.path.join(directory, entry))]
      print(f"Number of files in '{directory}': {len(files)}")
  except Exception as e:
      logger.error(f"Error: {e}")

# %% [markdown]
# ### Start

# %%
shutil.rmtree('/content/sample_data')

# %%
log_format = "%(asctime)s - %(levelname)s - %(message)s"
logging.basicConfig(filename="logs.log", filemode="w", format=log_format, level=logging.WARNING)

logger = logging.getLogger(__name__)
file_handler = logging.FileHandler('logs.log')
file_handler.setLevel(logging.WARNING)
formatter = logging.Formatter(log_format)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# %%
with tarfile.open(file, 'r:bz2') as tar:
  tar.extractall('/content/')

print(f"Extracted {file} @ {input_path}.")
# Out:
# Extracted /content/drive/MyDrive/Colab Notebooks/Dataset/eval.tar.bz2 @ /content/eval/.

# %%
folders = os.listdir(input_path)

for f in folders:
  files +=count_files(f'{input_path}/{f}')

print(f"Total files in {input_path} : {files}")
# Out:
# Total files in /content/eval/ : 78534

# %%
userdata.get('huggingface')
# Out:
# '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'

# %%
login("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",add_to_git_credential=True)
# Out:
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
create_repo("CodexAI/Eval4Deepseek-Coder", repo_type="dataset", private=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# RepoUrl('https://huggingface.co/datasets/CodexAI/Eval4Deepseek-Coder', endpoint='https://huggingface.co', repo_type='dataset', repo_id='CodexAI/Eval4Deepseek-Coder')

# %%
repo_url='https://huggingface.co/datasets/CodexAI/Eval4Deepseek-Coder'
repo_id = 'CodexAI/Eval4Deepseek-Coder'

repo = Repository(local_dir=output_path, clone_from=repo_url)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/datasets/CodexAI/Eval4Deepseek-Coder into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/datasets/CodexAI/Eval4Deepseek-Coder into local empty directory.

# %%
preprocess_dataset(input_path, output_path, context_type)

# %%
folders = os.listdir(output_path)
files = 0

for f in folders:
  if not os.path.isdir(f):
    count_files(f'{output_path}/{f}')
# Out:
# Number of files in '/content/Eval4Deepseek-Coder/43142077': 2
# Number of files in '/content/Eval4Deepseek-Coder/858685': 561
# Number of files in '/content/Eval4Deepseek-Coder/178486098': 8
# Number of files in '/content/Eval4Deepseek-Coder/87820447': 232
# Number of files in '/content/Eval4Deepseek-Coder/35230855': 33
# Number of files in '/content/Eval4Deepseek-Coder/58107893': 386
# Number of files in '/content/Eval4Deepseek-Coder/64902062': 1
# Number of files in '/content/Eval4Deepseek-Coder/198452291': 3
# Number of files in '/content/Eval4Deepseek-Coder/47121388': 32
# Number of files in '/content/Eval4Deepseek-Coder/243312367': 2
# Number of files in '/content/Eval4Deepseek-Coder/230760808': 5
# Number of files in '/content/Eval4Deepseek-Coder/4808693': 13
# Number of files in '/content/Eval4Deepseek-Coder/38732107': 178
# Number of files in '/content/Eval4Deepseek-Coder/66657283': 2
# Number of files in '/content/Eval4Deepseek-Coder/150133859': 478
# Number of files in '/content/Eval4Deepseek-Coder/49812577': 2
# Number of files in '/content/Eval4Deepseek-Coder/114630871': 832
# Number of files in '/content/Eval4Deepseek-Coder/8455875': 49
# Number of files in '/content/Eval4Deepseek-Coder/6684980': 8
# Number of files in '/content/Eval4Deepseek-Coder/69727127': 1
# Number of files in '/content/Eval4Deepseek-Coder/7010724': 41
# Number of files in '/content/Eval4Deepseek-Coder/99796571': 1
# Number of files in '/content/Eval4Deepseek-Coder/159218865': 102
# Number of files in '/content/Eval4Deepseek-Coder/174202612': 27
# Number of files in '/content/Eval4Deepseek-Coder/56153614': 51
# Number of files in '/content/Eval4Deepseek-Coder/206255831': 1
# Number of files in '/content/Eval4Deepseek-Coder/7770259': 42
# Number of files in '/content/Eval4Deepseek-Coder/12901602': 43
# Number of files in '/content/Eval4Deepseek-Coder/13353426': 328
# Number of files in '/content/Eval4Deepseek-Coder/9953682': 3
# Number of files in '/content/Eval4Deepseek-Coder/124001998': 432
# Number of files in '/content/Eval4Deepseek-Coder/25121397': 9
# Number of files in '/content/Eval4Deepseek-Coder/71576761': 43
# Number of files in '/content/Eval4Deepseek-Coder/247748530': 1
# Number of files in '/content/Eval4Deepseek-Coder/23634371': 10
# Number of files in '/content/Eval4Deepseek-Coder/38578729': 21
# Number of files in '/content/Eval4Deepseek-Coder/29608496': 43
# Number of files in '/content/Eval4Deepseek-Coder/68965963': 43
# Number of files in '/content/Eval4Deepseek-Coder/44920490': 5
# Number of files in '/content/Eval4Deepseek-Coder/111832512': 14
# Number of files in '/content/Eval4Deepseek-Coder/162486600': 383
# Number of files in '/content/Eval4Deepseek-Coder/96609869': 9
# Number of files in '/content/Eval4Deepseek-Coder/111789186': 24
# Number of files in '/content/Eval4Deepseek-Coder/89562636': 215
# Number of files in '/content/Eval4Deepseek-Coder/39831872': 146
# Number of files in '/content/Eval4Deepseek-Coder/178636495': 43
# Number of files in '/content/Eval4Deepseek-Coder/54175321': 14
# Number of files in '/content/Eval4Deepseek-Coder/25904690': 13
# Number of files in '/content/Eval4Deepseek-Coder/1568008': 383
# Number of files in '/content/Eval4Deepseek-Coder/22241929': 2
# Number of files in '/content/Eval4Deepseek-Coder/32166298': 411
# Number of files in '/content/Eval4Deepseek-Coder/32739388': 16
# Number of files in '/content/Eval4Deepseek-Coder/40829542': 6
# Number of files in '/content/Eval4Deepseek-Coder/152245376': 111
# Number of files in '/content/Eval4Deepseek-Coder/81057842': 7
# Number of files in '/content/Eval4Deepseek-Coder/22062596': 14
# Number of files in '/content/Eval4Deepseek-Coder/1529681': 5
# Number of files in '/content/Eval4Deepseek-Coder/20289822': 81
# Number of files in '/content/Eval4Deepseek-Coder/11673895': 39
# Number of files in '/content/Eval4Deepseek-Coder/34128918': 16
# Number of files in '/content/Eval4Deepseek-Coder/99116944': 50
# Number of files in '/content/Eval4Deepseek-Coder/10522020': 1868
# Number of files in '/content/Eval4Deepseek-Coder/80208107': 7
# Number of files in '/content/Eval4Deepseek-Coder/5391743': 15
# Number of files in '/content/Eval4Deepseek-Coder/87840586': 274
# Number of files in '/content/Eval4Deepseek-Coder/8686380': 101
# Number of files in '/content/Eval4Deepseek-Coder/5144132': 7
# Number of files in '/content/Eval4Deepseek-Coder/13036109': 15
# Number of files in '/content/Eval4Deepseek-Coder/194586350': 11
# Number of files in '/content/Eval4Deepseek-Coder/5837714': 7
# Number of files in '/content/Eval4Deepseek-Coder/22305416': 879
# Number of files in '/content/Eval4Deepseek-Coder/9303702': 4
# Number of files in '/content/Eval4Deepseek-Coder/5732934': 29
# Number of files in '/content/Eval4Deepseek-Coder/97738923': 7
# Number of files in '/content/Eval4Deepseek-Coder/130363261': 9
# Number of files in '/content/Eval4Deepseek-Coder/3672514': 1
# Number of files in '/content/Eval4Deepseek-Coder/7303047': 15
# Number of files in '/content/Eval4Deepseek-Coder/81022945': 13
# Number of files in '/content/Eval4Deepseek-Coder/144457010': 13
# Number of files in '/content/Eval4Deepseek-Coder/111915134': 399
# Number of files in '/content/Eval4Deepseek-Coder/4858466': 94
# Number of files in '/content/Eval4Deepseek-Coder/49952701': 56
# Number of files in '/content/Eval4Deepseek-Coder/147515984': 3
# Number of files in '/content/Eval4Deepseek-Coder/169215839': 9
# Number of files in '/content/Eval4Deepseek-Coder/13392416': 59
# Number of files in '/content/Eval4Deepseek-Coder/37151000': 3
# Number of files in '/content/Eval4Deepseek-Coder/93012016': 78
# Number of files in '/content/Eval4Deepseek-Coder/139959854': 224
# Number of files in '/content/Eval4Deepseek-Coder/21048299': 28
# Number of files in '/content/Eval4Deepseek-Coder/84721935': 20
# Number of files in '/content/Eval4Deepseek-Coder/60179659': 5
# Number of files in '/content/Eval4Deepseek-Coder/15913767': 19
# Number of files in '/content/Eval4Deepseek-Coder/23360533': 11
# Number of files in '/content/Eval4Deepseek-Coder/206398': 424
# Number of files in '/content/Eval4Deepseek-Coder/4125347': 4
# Number of files in '/content/Eval4Deepseek-Coder/37631091': 7
# Number of files in '/content/Eval4Deepseek-Coder/4215600': 16
# Number of files in '/content/Eval4Deepseek-Coder/5797013': 173
# Number of files in '/content/Eval4Deepseek-Coder/66786740': 3
# Number of files in '/content/Eval4Deepseek-Coder/57972486': 10
# Number of files in '/content/Eval4Deepseek-Coder/93878516': 16
# Number of files in '/content/Eval4Deepseek-Coder/93466587': 3
# Number of files in '/content/Eval4Deepseek-Coder/125837419': 9
# Number of files in '/content/Eval4Deepseek-Coder/60178690': 63
# Number of files in '/content/Eval4Deepseek-Coder/288079': 8
# Number of files in '/content/Eval4Deepseek-Coder/6441969': 3
# Number of files in '/content/Eval4Deepseek-Coder/98556534': 5
# Number of files in '/content/Eval4Deepseek-Coder/24716200': 46
# Number of files in '/content/Eval4Deepseek-Coder/55416134': 1
# Number of files in '/content/Eval4Deepseek-Coder/26486958': 63
# Number of files in '/content/Eval4Deepseek-Coder/32086270': 6
# Number of files in '/content/Eval4Deepseek-Coder/44446117': 13
# Number of files in '/content/Eval4Deepseek-Coder/23956049': 22
# Number of files in '/content/Eval4Deepseek-Coder/8953373': 24
# Number of files in '/content/Eval4Deepseek-Coder/44994636': 417
# Number of files in '/content/Eval4Deepseek-Coder/115063846': 495
# Number of files in '/content/Eval4Deepseek-Coder/42457394': 222
# Number of files in '/content/Eval4Deepseek-Coder/19110630': 85
# Number of files in '/content/Eval4Deepseek-Coder/197791400': 2
# Number of files in '/content/Eval4Deepseek-Coder/182984652': 1
# Number of files in '/content/Eval4Deepseek-Coder/114789714': 3
# Number of files in '/content/Eval4Deepseek-Coder/37645458': 11
# Number of files in '/content/Eval4Deepseek-Coder/9189077': 1
# Number of files in '/content/Eval4Deepseek-Coder/195936879': 4
# Number of files in '/content/Eval4Deepseek-Coder/45111637': 20
# Number of files in '/content/Eval4Deepseek-Coder/172157587': 7
# Number of files in '/content/Eval4Deepseek-Coder/102089663': 4
# Number of files in '/content/Eval4Deepseek-Coder/75882172': 465
# Number of files in '/content/Eval4Deepseek-Coder/187845287': 2
# Number of files in '/content/Eval4Deepseek-Coder/159691519': 77
# Number of files in '/content/Eval4Deepseek-Coder/2686932': 2
# Number of files in '/content/Eval4Deepseek-Coder/4599064': 284
# Number of files in '/content/Eval4Deepseek-Coder/7959279': 335
# Number of files in '/content/Eval4Deepseek-Coder/39380991': 12
# Number of files in '/content/Eval4Deepseek-Coder/10005385': 387
# Number of files in '/content/Eval4Deepseek-Coder/71704018': 10
# Number of files in '/content/Eval4Deepseek-Coder/33185377': 51
# Number of files in '/content/Eval4Deepseek-Coder/50718196': 662
# Number of files in '/content/Eval4Deepseek-Coder/120005344': 8
# Number of files in '/content/Eval4Deepseek-Coder/57073755': 63
# Number of files in '/content/Eval4Deepseek-Coder/9883230': 14
# Number of files in '/content/Eval4Deepseek-Coder/27610895': 2
# Number of files in '/content/Eval4Deepseek-Coder/200694582': 15
# Number of files in '/content/Eval4Deepseek-Coder/17298162': 6
# Number of files in '/content/Eval4Deepseek-Coder/129250921': 2
# Number of files in '/content/Eval4Deepseek-Coder/132634193': 15
# Number of files in '/content/Eval4Deepseek-Coder/14615932': 8
# Number of files in '/content/Eval4Deepseek-Coder/117021824': 60
# Number of files in '/content/Eval4Deepseek-Coder/44138404': 1
# Number of files in '/content/Eval4Deepseek-Coder/143344440': 220
# Number of files in '/content/Eval4Deepseek-Coder/2442452': 9
# Number of files in '/content/Eval4Deepseek-Coder/9499422': 111
# Number of files in '/content/Eval4Deepseek-Coder/89630500': 1
# Number of files in '/content/Eval4Deepseek-Coder/119123174': 56
# Number of files in '/content/Eval4Deepseek-Coder/223957373': 18
# Number of files in '/content/Eval4Deepseek-Coder/8575948': 159
# Number of files in '/content/Eval4Deepseek-Coder/108854086': 42
# Number of files in '/content/Eval4Deepseek-Coder/36870975': 1
# Number of files in '/content/Eval4Deepseek-Coder/107884359': 1
# Number of files in '/content/Eval4Deepseek-Coder/13675190': 4
# Number of files in '/content/Eval4Deepseek-Coder/4245170': 2
# Number of files in '/content/Eval4Deepseek-Coder/71119502': 542
# Number of files in '/content/Eval4Deepseek-Coder/46648544': 124
# Number of files in '/content/Eval4Deepseek-Coder/52853557': 27
# Number of files in '/content/Eval4Deepseek-Coder/50372538': 6
# Number of files in '/content/Eval4Deepseek-Coder/141896179': 8
# Number of files in '/content/Eval4Deepseek-Coder/97011177': 1
# Number of files in '/content/Eval4Deepseek-Coder/149943347': 1
# Number of files in '/content/Eval4Deepseek-Coder/55405035': 2
# Number of files in '/content/Eval4Deepseek-Coder/238088467': 68
# Number of files in '/content/Eval4Deepseek-Coder/597431': 180
# Number of files in '/content/Eval4Deepseek-Coder/92601170': 4
# Number of files in '/content/Eval4Deepseek-Coder/89879438': 41
# Number of files in '/content/Eval4Deepseek-Coder/195009151': 7
# Number of files in '/content/Eval4Deepseek-Coder/73000313': 62
# Number of files in '/content/Eval4Deepseek-Coder/78372835': 3
# Number of files in '/content/Eval4Deepseek-Coder/3945055': 21
# Number of files in '/content/Eval4Deepseek-Coder/32312233': 1
# Number of files in '/content/Eval4Deepseek-Coder/22175720': 60
# Number of files in '/content/Eval4Deepseek-Coder/77239977': 4
# Number of files in '/content/Eval4Deepseek-Coder/19518566': 1
# Number of files in '/content/Eval4Deepseek-Coder/3397224': 15
# Number of files in '/content/Eval4Deepseek-Coder/3405574': 10
# Number of files in '/content/Eval4Deepseek-Coder/185188267': 2
# Number of files in '/content/Eval4Deepseek-Coder/104779833': 23
# Number of files in '/content/Eval4Deepseek-Coder/24652385': 23
# Number of files in '/content/Eval4Deepseek-Coder/14068061': 20
# Number of files in '/content/Eval4Deepseek-Coder/18570156': 5
# Number of files in '/content/Eval4Deepseek-Coder/18442381': 471
# Number of files in '/content/Eval4Deepseek-Coder/115495336': 18
# Number of files in '/content/Eval4Deepseek-Coder/20246038': 35
# Number of files in '/content/Eval4Deepseek-Coder/49203125': 1
# Number of files in '/content/Eval4Deepseek-Coder/5372003': 32
# Number of files in '/content/Eval4Deepseek-Coder/115942239': 2
# Number of files in '/content/Eval4Deepseek-Coder/936567': 26
# Number of files in '/content/Eval4Deepseek-Coder/9945428': 8
# Number of files in '/content/Eval4Deepseek-Coder/76713852': 13
# Number of files in '/content/Eval4Deepseek-Coder/13357953': 2
# Number of files in '/content/Eval4Deepseek-Coder/22121632': 1
# Number of files in '/content/Eval4Deepseek-Coder/69105460': 5
# Number of files in '/content/Eval4Deepseek-Coder/10808572': 64
# Number of files in '/content/Eval4Deepseek-Coder/9509407': 23
# Number of files in '/content/Eval4Deepseek-Coder/322018': 233
# Number of files in '/content/Eval4Deepseek-Coder/83011130': 60
# Number of files in '/content/Eval4Deepseek-Coder/13380298': 24
# Number of files in '/content/Eval4Deepseek-Coder/23484534': 15
# Number of files in '/content/Eval4Deepseek-Coder/66210591': 23
# Number of files in '/content/Eval4Deepseek-Coder/170116597': 1
# Number of files in '/content/Eval4Deepseek-Coder/74431644': 676
# Number of files in '/content/Eval4Deepseek-Coder/227847226': 2
# Number of files in '/content/Eval4Deepseek-Coder/79203986': 18
# Number of files in '/content/Eval4Deepseek-Coder/47506301': 31
# Number of files in '/content/Eval4Deepseek-Coder/95226986': 1
# Number of files in '/content/Eval4Deepseek-Coder/145134450': 2
# Number of files in '/content/Eval4Deepseek-Coder/160901526': 2
# Number of files in '/content/Eval4Deepseek-Coder/69459090': 28
# Number of files in '/content/Eval4Deepseek-Coder/12650679': 83
# Number of files in '/content/Eval4Deepseek-Coder/84315364': 71
# Number of files in '/content/Eval4Deepseek-Coder/5181735': 5
# Number of files in '/content/Eval4Deepseek-Coder/12537665': 235
# Number of files in '/content/Eval4Deepseek-Coder/1389172': 13
# Number of files in '/content/Eval4Deepseek-Coder/150363647': 2
# Number of files in '/content/Eval4Deepseek-Coder/20544243': 11
# Number of files in '/content/Eval4Deepseek-Coder/67041316': 165
# Number of files in '/content/Eval4Deepseek-Coder/15312233': 115
# Number of files in '/content/Eval4Deepseek-Coder/76684425': 112
# Number of files in '/content/Eval4Deepseek-Coder/85618633': 7
# Number of files in '/content/Eval4Deepseek-Coder/18559131': 435
# Number of files in '/content/Eval4Deepseek-Coder/44863004': 15
# Number of files in '/content/Eval4Deepseek-Coder/36558220': 31
# Number of files in '/content/Eval4Deepseek-Coder/117251051': 3
# Number of files in '/content/Eval4Deepseek-Coder/185368847': 1
# Number of files in '/content/Eval4Deepseek-Coder/209464668': 118
# Number of files in '/content/Eval4Deepseek-Coder/4348575': 62
# Number of files in '/content/Eval4Deepseek-Coder/19818273': 47
# Number of files in '/content/Eval4Deepseek-Coder/105860078': 30
# Number of files in '/content/Eval4Deepseek-Coder/96970120': 35
# Number of files in '/content/Eval4Deepseek-Coder/11658921': 20
# Number of files in '/content/Eval4Deepseek-Coder/101228354': 35
# Number of files in '/content/Eval4Deepseek-Coder/19863325': 88
# Number of files in '/content/Eval4Deepseek-Coder/149637214': 3
# Number of files in '/content/Eval4Deepseek-Coder/88274548': 1
# Number of files in '/content/Eval4Deepseek-Coder/21636061': 4
# Number of files in '/content/Eval4Deepseek-Coder/2489042': 68
# Number of files in '/content/Eval4Deepseek-Coder/105686726': 13
# Number of files in '/content/Eval4Deepseek-Coder/19955501': 16
# Number of files in '/content/Eval4Deepseek-Coder/149235066': 4
# Number of files in '/content/Eval4Deepseek-Coder/.git': 7
# Number of files in '/content/Eval4Deepseek-Coder/94986865': 8
# Number of files in '/content/Eval4Deepseek-Coder/16148181': 24
# Number of files in '/content/Eval4Deepseek-Coder/16891404': 4
# Number of files in '/content/Eval4Deepseek-Coder/100464616': 68
# Number of files in '/content/Eval4Deepseek-Coder/88403146': 3
# Number of files in '/content/Eval4Deepseek-Coder/33903657': 22
# Number of files in '/content/Eval4Deepseek-Coder/28002639': 10
# Number of files in '/content/Eval4Deepseek-Coder/206357': 67
# Number of files in '/content/Eval4Deepseek-Coder/43548435': 7
# Number of files in '/content/Eval4Deepseek-Coder/69549126': 9
# Number of files in '/content/Eval4Deepseek-Coder/2884524': 7
# Number of files in '/content/Eval4Deepseek-Coder/3299865': 1
# Number of files in '/content/Eval4Deepseek-Coder/98103322': 20
# Number of files in '/content/Eval4Deepseek-Coder/72740687': 318
# Number of files in '/content/Eval4Deepseek-Coder/36954340': 4
# Number of files in '/content/Eval4Deepseek-Coder/59626114': 6
# Number of files in '/content/Eval4Deepseek-Coder/50429558': 27
# Number of files in '/content/Eval4Deepseek-Coder/171643056': 7
# Number of files in '/content/Eval4Deepseek-Coder/52232455': 1
# Number of files in '/content/Eval4Deepseek-Coder/28972983': 6
# Number of files in '/content/Eval4Deepseek-Coder/83850760': 7
# Number of files in '/content/Eval4Deepseek-Coder/17637707': 1215
# Number of files in '/content/Eval4Deepseek-Coder/13322751': 384
# Number of files in '/content/Eval4Deepseek-Coder/62426066': 15
# Number of files in '/content/Eval4Deepseek-Coder/130808918': 130
# Number of files in '/content/Eval4Deepseek-Coder/11821201': 982
# Number of files in '/content/Eval4Deepseek-Coder/71292480': 37
# Number of files in '/content/Eval4Deepseek-Coder/25032213': 59
# Number of files in '/content/Eval4Deepseek-Coder/6205252': 168
# Number of files in '/content/Eval4Deepseek-Coder/712229': 161
# Number of files in '/content/Eval4Deepseek-Coder/27098387': 4
# Number of files in '/content/Eval4Deepseek-Coder/166323982': 73
# Number of files in '/content/Eval4Deepseek-Coder/133938603': 7
# Number of files in '/content/Eval4Deepseek-Coder/2868402': 4
# Number of files in '/content/Eval4Deepseek-Coder/40583917': 11
# Number of files in '/content/Eval4Deepseek-Coder/90249710': 7
# Number of files in '/content/Eval4Deepseek-Coder/77389964': 17
# Number of files in '/content/Eval4Deepseek-Coder/38271397': 1
# Number of files in '/content/Eval4Deepseek-Coder/187124580': 2
# Number of files in '/content/Eval4Deepseek-Coder/162537587': 10
# Number of files in '/content/Eval4Deepseek-Coder/25808536': 3
# Number of files in '/content/Eval4Deepseek-Coder/81102965': 21
# Number of files in '/content/Eval4Deepseek-Coder/206346': 2
# Number of files in '/content/Eval4Deepseek-Coder/15253562': 5
# Number of files in '/content/Eval4Deepseek-Coder/34387597': 496
# Number of files in '/content/Eval4Deepseek-Coder/170586975': 63
# Number of files in '/content/Eval4Deepseek-Coder/39381014': 11
# Number of files in '/content/Eval4Deepseek-Coder/1585278': 13
# Number of files in '/content/Eval4Deepseek-Coder/41939338': 18
# Number of files in '/content/Eval4Deepseek-Coder/2564522': 58
# Number of files in '/content/Eval4Deepseek-Coder/18213453': 121
# Number of files in '/content/Eval4Deepseek-Coder/164700318': 3
# Number of files in '/content/Eval4Deepseek-Coder/34776974': 15
# Number of files in '/content/Eval4Deepseek-Coder/16900555': 21
# Number of files in '/content/Eval4Deepseek-Coder/50205742': 628
# Number of files in '/content/Eval4Deepseek-Coder/2893108': 55
# Number of files in '/content/Eval4Deepseek-Coder/13970820': 5
# Number of files in '/content/Eval4Deepseek-Coder/4732208': 33
# Number of files in '/content/Eval4Deepseek-Coder/17034170': 3
# Number of files in '/content/Eval4Deepseek-Coder/157569792': 25
# Number of files in '/content/Eval4Deepseek-Coder/196555066': 1
# Number of files in '/content/Eval4Deepseek-Coder/67256778': 3
# Number of files in '/content/Eval4Deepseek-Coder/167330257': 177
# Number of files in '/content/Eval4Deepseek-Coder/33893138': 55
# Number of files in '/content/Eval4Deepseek-Coder/51262014': 71
# Number of files in '/content/Eval4Deepseek-Coder/35483832': 13
# Number of files in '/content/Eval4Deepseek-Coder/19181491': 27
# Number of files in '/content/Eval4Deepseek-Coder/65708035': 8
# Number of files in '/content/Eval4Deepseek-Coder/45755430': 104
# Number of files in '/content/Eval4Deepseek-Coder/12518614': 2
# Number of files in '/content/Eval4Deepseek-Coder/24651738': 34
# Number of files in '/content/Eval4Deepseek-Coder/58914927': 1
# Number of files in '/content/Eval4Deepseek-Coder/11179945': 8
# Number of files in '/content/Eval4Deepseek-Coder/80898327': 58
# Number of files in '/content/Eval4Deepseek-Coder/18146125': 98
# Number of files in '/content/Eval4Deepseek-Coder/241224534': 10
# Number of files in '/content/Eval4Deepseek-Coder/2078882': 1
# Number of files in '/content/Eval4Deepseek-Coder/30952948': 1361
# Number of files in '/content/Eval4Deepseek-Coder/50157836': 2
# Number of files in '/content/Eval4Deepseek-Coder/42078482': 68
# Number of files in '/content/Eval4Deepseek-Coder/73109468': 29
# Number of files in '/content/Eval4Deepseek-Coder/48654534': 147
# Number of files in '/content/Eval4Deepseek-Coder/29480568': 2905
# Number of files in '/content/Eval4Deepseek-Coder/81920458': 266
# Number of files in '/content/Eval4Deepseek-Coder/177212349': 450
# Number of files in '/content/Eval4Deepseek-Coder/174291606': 1
# Number of files in '/content/Eval4Deepseek-Coder/133340671': 148
# Number of files in '/content/Eval4Deepseek-Coder/6808742': 4
# Number of files in '/content/Eval4Deepseek-Coder/53518706': 13
# Number of files in '/content/Eval4Deepseek-Coder/133533106': 10
# Number of files in '/content/Eval4Deepseek-Coder/12485637': 35
# Number of files in '/content/Eval4Deepseek-Coder/103604931': 6
# Number of files in '/content/Eval4Deepseek-Coder/12793012': 6
# Number of files in '/content/Eval4Deepseek-Coder/155342006': 2
# Number of files in '/content/Eval4Deepseek-Coder/98459144': 74
# Number of files in '/content/Eval4Deepseek-Coder/8262365': 1165
# Number of files in '/content/Eval4Deepseek-Coder/46489668': 72
# Number of files in '/content/Eval4Deepseek-Coder/116761172': 740
# Number of files in '/content/Eval4Deepseek-Coder/167005003': 29
# Number of files in '/content/Eval4Deepseek-Coder/18111614': 7
# Number of files in '/content/Eval4Deepseek-Coder/79160472': 113
# Number of files in '/content/Eval4Deepseek-Coder/71078377': 5
# Number of files in '/content/Eval4Deepseek-Coder/1783085': 55
# Number of files in '/content/Eval4Deepseek-Coder/2265146': 23
# Number of files in '/content/Eval4Deepseek-Coder/151477580': 72
# Number of files in '/content/Eval4Deepseek-Coder/38562251': 19
# Number of files in '/content/Eval4Deepseek-Coder/20089859': 126
# Number of files in '/content/Eval4Deepseek-Coder/54601914': 4
# Number of files in '/content/Eval4Deepseek-Coder/183579037': 7
# Number of files in '/content/Eval4Deepseek-Coder/31685450': 9
# Number of files in '/content/Eval4Deepseek-Coder/70282465': 8
# Number of files in '/content/Eval4Deepseek-Coder/13300550': 14
# Number of files in '/content/Eval4Deepseek-Coder/46334349': 6
# Number of files in '/content/Eval4Deepseek-Coder/95449551': 62
# Number of files in '/content/Eval4Deepseek-Coder/64151177': 9
# Number of files in '/content/Eval4Deepseek-Coder/98270619': 1
# Number of files in '/content/Eval4Deepseek-Coder/4077804': 13
# Number of files in '/content/Eval4Deepseek-Coder/240468': 8
# Number of files in '/content/Eval4Deepseek-Coder/160934908': 15
# Number of files in '/content/Eval4Deepseek-Coder/73832768': 3
# Number of files in '/content/Eval4Deepseek-Coder/74285105': 27
# Number of files in '/content/Eval4Deepseek-Coder/67461402': 128
# Number of files in '/content/Eval4Deepseek-Coder/84871568': 7
# Number of files in '/content/Eval4Deepseek-Coder/28174336': 46
# Number of files in '/content/Eval4Deepseek-Coder/35602142': 37
# Number of files in '/content/Eval4Deepseek-Coder/95474825': 2
# Number of files in '/content/Eval4Deepseek-Coder/92945138': 37
# Number of files in '/content/Eval4Deepseek-Coder/81160': 39
# Number of files in '/content/Eval4Deepseek-Coder/132033525': 13
# Number of files in '/content/Eval4Deepseek-Coder/72322767': 5
# Number of files in '/content/Eval4Deepseek-Coder/88201676': 5
# Number of files in '/content/Eval4Deepseek-Coder/119891417': 30
# Number of files in '/content/Eval4Deepseek-Coder/51046991': 1
# Number of files in '/content/Eval4Deepseek-Coder/55768282': 4
# Number of files in '/content/Eval4Deepseek-Coder/77243612': 10
# Number of files in '/content/Eval4Deepseek-Coder/142377858': 16
# Number of files in '/content/Eval4Deepseek-Coder/51512653': 24
# Number of files in '/content/Eval4Deepseek-Coder/169665962': 10
# Number of files in '/content/Eval4Deepseek-Coder/76238742': 24
# Number of files in '/content/Eval4Deepseek-Coder/21611038': 1
# Number of files in '/content/Eval4Deepseek-Coder/30521489': 265
# Number of files in '/content/Eval4Deepseek-Coder/23926754': 610
# Number of files in '/content/Eval4Deepseek-Coder/153312678': 46
# Number of files in '/content/Eval4Deepseek-Coder/66030306': 104
# Number of files in '/content/Eval4Deepseek-Coder/75693309': 204
# Number of files in '/content/Eval4Deepseek-Coder/338397': 176
# Number of files in '/content/Eval4Deepseek-Coder/24880683': 13
# Number of files in '/content/Eval4Deepseek-Coder/2996995': 2
# Number of files in '/content/Eval4Deepseek-Coder/95919396': 15
# Number of files in '/content/Eval4Deepseek-Coder/83766696': 1
# Number of files in '/content/Eval4Deepseek-Coder/19182176': 1
# Number of files in '/content/Eval4Deepseek-Coder/4877687': 24
# Number of files in '/content/Eval4Deepseek-Coder/42647087': 4
# Number of files in '/content/Eval4Deepseek-Coder/160148747': 14
# Number of files in '/content/Eval4Deepseek-Coder/153603492': 25
# Number of files in '/content/Eval4Deepseek-Coder/17234441': 17
# Number of files in '/content/Eval4Deepseek-Coder/63166161': 51
# Number of files in '/content/Eval4Deepseek-Coder/1011634': 12
# Number of files in '/content/Eval4Deepseek-Coder/172187': 4
# Number of files in '/content/Eval4Deepseek-Coder/63559666': 12
# Number of files in '/content/Eval4Deepseek-Coder/61747796': 2
# Number of files in '/content/Eval4Deepseek-Coder/50107211': 4
# Number of files in '/content/Eval4Deepseek-Coder/84104620': 152
# Number of files in '/content/Eval4Deepseek-Coder/12453634': 129
# Number of files in '/content/Eval4Deepseek-Coder/23319185': 22
# Number of files in '/content/Eval4Deepseek-Coder/745456': 20
# Number of files in '/content/Eval4Deepseek-Coder/1550174': 3
# Number of files in '/content/Eval4Deepseek-Coder/43186057': 83
# Number of files in '/content/Eval4Deepseek-Coder/43017914': 23
# Number of files in '/content/Eval4Deepseek-Coder/23343072': 100
# Number of files in '/content/Eval4Deepseek-Coder/41371218': 2
# Number of files in '/content/Eval4Deepseek-Coder/65368111': 34
# Number of files in '/content/Eval4Deepseek-Coder/2789538': 1
# Number of files in '/content/Eval4Deepseek-Coder/85361423': 85
# Number of files in '/content/Eval4Deepseek-Coder/12008679': 12
# Number of files in '/content/Eval4Deepseek-Coder/12204684': 124
# Number of files in '/content/Eval4Deepseek-Coder/8410721': 11
# Number of files in '/content/Eval4Deepseek-Coder/89067898': 1
# Number of files in '/content/Eval4Deepseek-Coder/77034155': 3
# Number of files in '/content/Eval4Deepseek-Coder/45170743': 2
# Number of files in '/content/Eval4Deepseek-Coder/4018481': 48
# Number of files in '/content/Eval4Deepseek-Coder/134505330': 2424
# Number of files in '/content/Eval4Deepseek-Coder/67806778': 5
# Number of files in '/content/Eval4Deepseek-Coder/115198687': 783
# Number of files in '/content/Eval4Deepseek-Coder/31415856': 54
# Number of files in '/content/Eval4Deepseek-Coder/206427': 395
# Number of files in '/content/Eval4Deepseek-Coder/2948949': 1
# Number of files in '/content/Eval4Deepseek-Coder/6966619': 31
# Number of files in '/content/Eval4Deepseek-Coder/91349782': 8
# Number of files in '/content/Eval4Deepseek-Coder/17049428': 85
# Number of files in '/content/Eval4Deepseek-Coder/127753126': 535
# Number of files in '/content/Eval4Deepseek-Coder/114670393': 6
# Number of files in '/content/Eval4Deepseek-Coder/62373731': 31
# Number of files in '/content/Eval4Deepseek-Coder/148458099': 1
# Number of files in '/content/Eval4Deepseek-Coder/129283853': 90
# Number of files in '/content/Eval4Deepseek-Coder/48369985': 47
# Number of files in '/content/Eval4Deepseek-Coder/41348333': 93
# Number of files in '/content/Eval4Deepseek-Coder/51447533': 19
# Number of files in '/content/Eval4Deepseek-Coder/1581656': 5
# Number of files in '/content/Eval4Deepseek-Coder/196973701': 37
# Number of files in '/content/Eval4Deepseek-Coder/12314259': 5
# Number of files in '/content/Eval4Deepseek-Coder/209630794': 19
# Number of files in '/content/Eval4Deepseek-Coder/147622875': 2
# Number of files in '/content/Eval4Deepseek-Coder/197364349': 168
# Number of files in '/content/Eval4Deepseek-Coder/74151777': 33
# Number of files in '/content/Eval4Deepseek-Coder/77700697': 3
# Number of files in '/content/Eval4Deepseek-Coder/1118699': 44
# Number of files in '/content/Eval4Deepseek-Coder/70295212': 46
# Number of files in '/content/Eval4Deepseek-Coder/722432': 2
# Number of files in '/content/Eval4Deepseek-Coder/160013598': 3
# Number of files in '/content/Eval4Deepseek-Coder/76400426': 54
# Number of files in '/content/Eval4Deepseek-Coder/102583752': 35
# Number of files in '/content/Eval4Deepseek-Coder/22252491': 2
# Number of files in '/content/Eval4Deepseek-Coder/135922312': 4
# Number of files in '/content/Eval4Deepseek-Coder/9096425': 178
# Number of files in '/content/Eval4Deepseek-Coder/20415251': 1
# Number of files in '/content/Eval4Deepseek-Coder/10283615': 114
# Number of files in '/content/Eval4Deepseek-Coder/41406342': 1
# Number of files in '/content/Eval4Deepseek-Coder/38562009': 639
# Number of files in '/content/Eval4Deepseek-Coder/114262958': 14
# Number of files in '/content/Eval4Deepseek-Coder/64625768': 9
# Number of files in '/content/Eval4Deepseek-Coder/43409398': 33
# Number of files in '/content/Eval4Deepseek-Coder/84976265': 115
# Number of files in '/content/Eval4Deepseek-Coder/16525446': 34
# Number of files in '/content/Eval4Deepseek-Coder/157695023': 12
# Number of files in '/content/Eval4Deepseek-Coder/56061422': 102
# Number of files in '/content/Eval4Deepseek-Coder/24680874': 7
# Number of files in '/content/Eval4Deepseek-Coder/50872805': 213
# Number of files in '/content/Eval4Deepseek-Coder/1768088': 25
# Number of files in '/content/Eval4Deepseek-Coder/94637589': 17
# Number of files in '/content/Eval4Deepseek-Coder/209573855': 45
# Number of files in '/content/Eval4Deepseek-Coder/80383682': 4
# Number of files in '/content/Eval4Deepseek-Coder/161032188': 11
# Number of files in '/content/Eval4Deepseek-Coder/2842372': 3
# Number of files in '/content/Eval4Deepseek-Coder/119583553': 3
# Number of files in '/content/Eval4Deepseek-Coder/502666': 1
# Number of files in '/content/Eval4Deepseek-Coder/191807118': 3
# Number of files in '/content/Eval4Deepseek-Coder/49620246': 2
# Number of files in '/content/Eval4Deepseek-Coder/83142122': 12
# Number of files in '/content/Eval4Deepseek-Coder/22574511': 43
# Number of files in '/content/Eval4Deepseek-Coder/72735946': 28
# Number of files in '/content/Eval4Deepseek-Coder/44659948': 2
# Number of files in '/content/Eval4Deepseek-Coder/93992855': 1
# Number of files in '/content/Eval4Deepseek-Coder/78477907': 31
# Number of files in '/content/Eval4Deepseek-Coder/40808092': 55
# Number of files in '/content/Eval4Deepseek-Coder/88632627': 112
# Number of files in '/content/Eval4Deepseek-Coder/4248863': 62
# Number of files in '/content/Eval4Deepseek-Coder/66951768': 5
# Number of files in '/content/Eval4Deepseek-Coder/30971059': 6
# Number of files in '/content/Eval4Deepseek-Coder/112984186': 72
# Number of files in '/content/Eval4Deepseek-Coder/50105259': 4
# Number of files in '/content/Eval4Deepseek-Coder/21873687': 2
# Number of files in '/content/Eval4Deepseek-Coder/1529695': 17
# Number of files in '/content/Eval4Deepseek-Coder/34306730': 77
# Number of files in '/content/Eval4Deepseek-Coder/78874371': 1
# Number of files in '/content/Eval4Deepseek-Coder/4661744': 401
# Number of files in '/content/Eval4Deepseek-Coder/6937573': 551
# Number of files in '/content/Eval4Deepseek-Coder/73486254': 35
# Number of files in '/content/Eval4Deepseek-Coder/158166592': 17
# Number of files in '/content/Eval4Deepseek-Coder/62579712': 7
# Number of files in '/content/Eval4Deepseek-Coder/29032693': 1
# Number of files in '/content/Eval4Deepseek-Coder/23418517': 3126
# Number of files in '/content/Eval4Deepseek-Coder/317887': 2150
# Number of files in '/content/Eval4Deepseek-Coder/48711146': 1
# Number of files in '/content/Eval4Deepseek-Coder/46065432': 1
# Number of files in '/content/Eval4Deepseek-Coder/87317435': 88
# Number of files in '/content/Eval4Deepseek-Coder/37239241': 2
# Number of files in '/content/Eval4Deepseek-Coder/4524453': 1
# Number of files in '/content/Eval4Deepseek-Coder/60930425': 27
# Number of files in '/content/Eval4Deepseek-Coder/38347575': 2
# Number of files in '/content/Eval4Deepseek-Coder/51214397': 2
# Number of files in '/content/Eval4Deepseek-Coder/104583079': 3
# Number of files in '/content/Eval4Deepseek-Coder/61726276': 15
# Number of files in '/content/Eval4Deepseek-Coder/52867190': 133
# Number of files in '/content/Eval4Deepseek-Coder/1767747': 4
# Number of files in '/content/Eval4Deepseek-Coder/9421507': 7
# Number of files in '/content/Eval4Deepseek-Coder/66866914': 72
# Number of files in '/content/Eval4Deepseek-Coder/114161796': 1
# Number of files in '/content/Eval4Deepseek-Coder/34305209': 1
# Number of files in '/content/Eval4Deepseek-Coder/155893423': 1
# Number of files in '/content/Eval4Deepseek-Coder/39910458': 3
# Number of files in '/content/Eval4Deepseek-Coder/123806317': 1
# Number of files in '/content/Eval4Deepseek-Coder/9730186': 75
# Number of files in '/content/Eval4Deepseek-Coder/86760618': 2
# Number of files in '/content/Eval4Deepseek-Coder/168378794': 137
# Number of files in '/content/Eval4Deepseek-Coder/43707061': 10
# Number of files in '/content/Eval4Deepseek-Coder/56027154': 3
# Number of files in '/content/Eval4Deepseek-Coder/11993995': 5
# Number of files in '/content/Eval4Deepseek-Coder/177207682': 19
# Number of files in '/content/Eval4Deepseek-Coder/110329589': 12
# Number of files in '/content/Eval4Deepseek-Coder/11857228': 24
# Number of files in '/content/Eval4Deepseek-Coder/18830104': 190
# Number of files in '/content/Eval4Deepseek-Coder/163942355': 3
# Number of files in '/content/Eval4Deepseek-Coder/36165669': 20
# Number of files in '/content/Eval4Deepseek-Coder/26956767': 2
# Number of files in '/content/Eval4Deepseek-Coder/30350283': 144
# Number of files in '/content/Eval4Deepseek-Coder/122246958': 79
# Number of files in '/content/Eval4Deepseek-Coder/194663163': 13
# Number of files in '/content/Eval4Deepseek-Coder/91026662': 12
# Number of files in '/content/Eval4Deepseek-Coder/4810310': 83
# Number of files in '/content/Eval4Deepseek-Coder/18461065': 18
# Number of files in '/content/Eval4Deepseek-Coder/11341720': 2
# Number of files in '/content/Eval4Deepseek-Coder/88715252': 22
# Number of files in '/content/Eval4Deepseek-Coder/35316975': 8
# Number of files in '/content/Eval4Deepseek-Coder/71493045': 5
# Number of files in '/content/Eval4Deepseek-Coder/588395': 1
# Number of files in '/content/Eval4Deepseek-Coder/19312763': 1
# Number of files in '/content/Eval4Deepseek-Coder/228330020': 18
# Number of files in '/content/Eval4Deepseek-Coder/14179154': 117
# Number of files in '/content/Eval4Deepseek-Coder/42683316': 1
# Number of files in '/content/Eval4Deepseek-Coder/80352586': 57
# Number of files in '/content/Eval4Deepseek-Coder/135944962': 12
# Number of files in '/content/Eval4Deepseek-Coder/93520200': 996
# Number of files in '/content/Eval4Deepseek-Coder/89024696': 387
# Number of files in '/content/Eval4Deepseek-Coder/15365897': 263
# Number of files in '/content/Eval4Deepseek-Coder/125332958': 124
# ERROR:__main__:Error: [Errno 20] Not a directory: '/content/Eval4Deepseek-Coder/.gitattributes'
# Number of files in '/content/Eval4Deepseek-Coder/32808027': 178
# Number of files in '/content/Eval4Deepseek-Coder/29127570': 22
# Number of files in '/content/Eval4Deepseek-Coder/30702818': 163
# Number of files in '/content/Eval4Deepseek-Coder/88765628': 14
# Number of files in '/content/Eval4Deepseek-Coder/276256': 1
# Number of files in '/content/Eval4Deepseek-Coder/64314375': 98
# Number of files in '/content/Eval4Deepseek-Coder/20916592': 18
# Number of files in '/content/Eval4Deepseek-Coder/95094994': 4
# Number of files in '/content/Eval4Deepseek-Coder/123195802': 14
# Number of files in '/content/Eval4Deepseek-Coder/95005676': 286
# Number of files in '/content/Eval4Deepseek-Coder/26163430': 1166
# Number of files in '/content/Eval4Deepseek-Coder/7102335': 16
# Number of files in '/content/Eval4Deepseek-Coder/166056144': 590
# Number of files in '/content/Eval4Deepseek-Coder/34198359': 3
# Number of files in '/content/Eval4Deepseek-Coder/104750793': 183
# Number of files in '/content/Eval4Deepseek-Coder/160731309': 363
# Number of files in '/content/Eval4Deepseek-Coder/56354946': 43
# Number of files in '/content/Eval4Deepseek-Coder/174687251': 2
# Number of files in '/content/Eval4Deepseek-Coder/48688888': 13
# Number of files in '/content/Eval4Deepseek-Coder/113771986': 33
# Number of files in '/content/Eval4Deepseek-Coder/3484241': 30
# Number of files in '/content/Eval4Deepseek-Coder/6116698': 1
# Number of files in '/content/Eval4Deepseek-Coder/187811141': 46
# Number of files in '/content/Eval4Deepseek-Coder/1335544': 4
# Number of files in '/content/Eval4Deepseek-Coder/9977431': 80
# Number of files in '/content/Eval4Deepseek-Coder/8313187': 66
# Number of files in '/content/Eval4Deepseek-Coder/18646035': 2
# Number of files in '/content/Eval4Deepseek-Coder/77769341': 158
# Number of files in '/content/Eval4Deepseek-Coder/11236015': 16
# Number of files in '/content/Eval4Deepseek-Coder/1640502': 21
# Number of files in '/content/Eval4Deepseek-Coder/8735938': 4
# Number of files in '/content/Eval4Deepseek-Coder/80640282': 17
# Number of files in '/content/Eval4Deepseek-Coder/4393933': 154
# Number of files in '/content/Eval4Deepseek-Coder/49199017': 3
# Number of files in '/content/Eval4Deepseek-Coder/2128637': 157
# Number of files in '/content/Eval4Deepseek-Coder/179549243': 364
# Number of files in '/content/Eval4Deepseek-Coder/125133410': 12
# Number of files in '/content/Eval4Deepseek-Coder/35727196': 8
# Number of files in '/content/Eval4Deepseek-Coder/51104384': 40
# Number of files in '/content/Eval4Deepseek-Coder/16727992': 20
# Number of files in '/content/Eval4Deepseek-Coder/34007506': 490
# Number of files in '/content/Eval4Deepseek-Coder/177560704': 79
# Number of files in '/content/Eval4Deepseek-Coder/7334654': 37
# Number of files in '/content/Eval4Deepseek-Coder/88392053': 55
# Number of files in '/content/Eval4Deepseek-Coder/26259891': 31
# Number of files in '/content/Eval4Deepseek-Coder/178382654': 4
# Number of files in '/content/Eval4Deepseek-Coder/156833788': 4
# Number of files in '/content/Eval4Deepseek-Coder/3839218': 429
# Number of files in '/content/Eval4Deepseek-Coder/53649949': 41
# Number of files in '/content/Eval4Deepseek-Coder/46116537': 72
# Number of files in '/content/Eval4Deepseek-Coder/110390408': 2
# Number of files in '/content/Eval4Deepseek-Coder/42914044': 6
# Number of files in '/content/Eval4Deepseek-Coder/13554015': 13
# Number of files in '/content/Eval4Deepseek-Coder/32333558': 127
# Number of files in '/content/Eval4Deepseek-Coder/261751286': 23
# Number of files in '/content/Eval4Deepseek-Coder/32819066': 46
# Number of files in '/content/Eval4Deepseek-Coder/115072985': 15
# Number of files in '/content/Eval4Deepseek-Coder/19810546': 1
# Number of files in '/content/Eval4Deepseek-Coder/44382767': 9
# Number of files in '/content/Eval4Deepseek-Coder/148813146': 7
# Number of files in '/content/Eval4Deepseek-Coder/26166898': 15
# Number of files in '/content/Eval4Deepseek-Coder/83753680': 3
# Number of files in '/content/Eval4Deepseek-Coder/21690383': 53
# Number of files in '/content/Eval4Deepseek-Coder/22253918': 5
# Number of files in '/content/Eval4Deepseek-Coder/25397479': 36
# Number of files in '/content/Eval4Deepseek-Coder/152085711': 6
# Number of files in '/content/Eval4Deepseek-Coder/80792932': 10
# Number of files in '/content/Eval4Deepseek-Coder/112050324': 12
# Number of files in '/content/Eval4Deepseek-Coder/35824715': 3
# Number of files in '/content/Eval4Deepseek-Coder/78706143': 1
# Number of files in '/content/Eval4Deepseek-Coder/241153419': 56
# Number of files in '/content/Eval4Deepseek-Coder/7158649': 175
# Number of files in '/content/Eval4Deepseek-Coder/73936138': 94
# Number of files in '/content/Eval4Deepseek-Coder/52151431': 3
# Number of files in '/content/Eval4Deepseek-Coder/17339218': 18
# Number of files in '/content/Eval4Deepseek-Coder/29704282': 4
# Number of files in '/content/Eval4Deepseek-Coder/66956738': 13
# Number of files in '/content/Eval4Deepseek-Coder/116932005': 27
# Number of files in '/content/Eval4Deepseek-Coder/37871055': 68
# Number of files in '/content/Eval4Deepseek-Coder/5796756': 29
# Number of files in '/content/Eval4Deepseek-Coder/1387559': 1
# Number of files in '/content/Eval4Deepseek-Coder/80633575': 4
# Number of files in '/content/Eval4Deepseek-Coder/53288089': 5
# Number of files in '/content/Eval4Deepseek-Coder/7728562': 80
# Number of files in '/content/Eval4Deepseek-Coder/8366048': 21
# Number of files in '/content/Eval4Deepseek-Coder/24352948': 1
# Number of files in '/content/Eval4Deepseek-Coder/8059194': 4
# Number of files in '/content/Eval4Deepseek-Coder/102138890': 2
# Number of files in '/content/Eval4Deepseek-Coder/56667109': 87
# Number of files in '/content/Eval4Deepseek-Coder/19525958': 130
# Number of files in '/content/Eval4Deepseek-Coder/54595273': 1
# Number of files in '/content/Eval4Deepseek-Coder/47342191': 2
# Number of files in '/content/Eval4Deepseek-Coder/58144490': 38
# Number of files in '/content/Eval4Deepseek-Coder/110584604': 5
# Number of files in '/content/Eval4Deepseek-Coder/3641311': 15
# Number of files in '/content/Eval4Deepseek-Coder/9652998': 23
# Number of files in '/content/Eval4Deepseek-Coder/60534182': 32
# Number of files in '/content/Eval4Deepseek-Coder/208900041': 3
# Number of files in '/content/Eval4Deepseek-Coder/70442779': 4
# Number of files in '/content/Eval4Deepseek-Coder/107542443': 21
# Number of files in '/content/Eval4Deepseek-Coder/206341': 27
# Number of files in '/content/Eval4Deepseek-Coder/117292444': 5
# Number of files in '/content/Eval4Deepseek-Coder/8752619': 85
# Number of files in '/content/Eval4Deepseek-Coder/134795070': 12
# Number of files in '/content/Eval4Deepseek-Coder/132375056': 158
# Number of files in '/content/Eval4Deepseek-Coder/40052051': 1
# Number of files in '/content/Eval4Deepseek-Coder/96774602': 32
# Number of files in '/content/Eval4Deepseek-Coder/36956708': 19
# Number of files in '/content/Eval4Deepseek-Coder/22323519': 1
# Number of files in '/content/Eval4Deepseek-Coder/86993832': 2
# Number of files in '/content/Eval4Deepseek-Coder/81968413': 356
# Number of files in '/content/Eval4Deepseek-Coder/105876502': 9
# Number of files in '/content/Eval4Deepseek-Coder/6903417': 44
# Number of files in '/content/Eval4Deepseek-Coder/79636769': 21
# Number of files in '/content/Eval4Deepseek-Coder/69371441': 1
# Number of files in '/content/Eval4Deepseek-Coder/52610929': 4
# Number of files in '/content/Eval4Deepseek-Coder/3181606': 8
# Number of files in '/content/Eval4Deepseek-Coder/60702089': 36
# Number of files in '/content/Eval4Deepseek-Coder/59146760': 23
# Number of files in '/content/Eval4Deepseek-Coder/99995945': 97
# Number of files in '/content/Eval4Deepseek-Coder/3487509': 75
# Number of files in '/content/Eval4Deepseek-Coder/7729948': 62
# Number of files in '/content/Eval4Deepseek-Coder/224855469': 12
# Number of files in '/content/Eval4Deepseek-Coder/14528678': 468
# Number of files in '/content/Eval4Deepseek-Coder/124938636': 1
# Number of files in '/content/Eval4Deepseek-Coder/40189580': 4
# Number of files in '/content/Eval4Deepseek-Coder/20448696': 150
# Number of files in '/content/Eval4Deepseek-Coder/4841075': 101
# Number of files in '/content/Eval4Deepseek-Coder/25156382': 2
# Number of files in '/content/Eval4Deepseek-Coder/81465478': 32
# Number of files in '/content/Eval4Deepseek-Coder/194234746': 48
# Number of files in '/content/Eval4Deepseek-Coder/10971357': 22
# Number of files in '/content/Eval4Deepseek-Coder/38078052': 70
# Number of files in '/content/Eval4Deepseek-Coder/71868774': 8
# Number of files in '/content/Eval4Deepseek-Coder/60586822': 2
# Number of files in '/content/Eval4Deepseek-Coder/49122768': 1
# Number of files in '/content/Eval4Deepseek-Coder/7179680': 7
# Number of files in '/content/Eval4Deepseek-Coder/33442556': 3
# Number of files in '/content/Eval4Deepseek-Coder/51712220': 4
# Number of files in '/content/Eval4Deepseek-Coder/157534056': 1
# Number of files in '/content/Eval4Deepseek-Coder/28566133': 15
# Number of files in '/content/Eval4Deepseek-Coder/93025616': 9
# Number of files in '/content/Eval4Deepseek-Coder/2958704': 5
# Number of files in '/content/Eval4Deepseek-Coder/166615086': 13
# Number of files in '/content/Eval4Deepseek-Coder/32882863': 42
# Number of files in '/content/Eval4Deepseek-Coder/164891999': 3
# Number of files in '/content/Eval4Deepseek-Coder/3604595': 2
# Number of files in '/content/Eval4Deepseek-Coder/41348334': 212
# Number of files in '/content/Eval4Deepseek-Coder/35542092': 6
# Number of files in '/content/Eval4Deepseek-Coder/32437859': 41
# Number of files in '/content/Eval4Deepseek-Coder/118326890': 6
# Number of files in '/content/Eval4Deepseek-Coder/5973732': 331
# Number of files in '/content/Eval4Deepseek-Coder/49026875': 1
# Number of files in '/content/Eval4Deepseek-Coder/1100144': 580
# Number of files in '/content/Eval4Deepseek-Coder/41330076': 91
# Number of files in '/content/Eval4Deepseek-Coder/18222972': 1
# Number of files in '/content/Eval4Deepseek-Coder/35274833': 3
# Number of files in '/content/Eval4Deepseek-Coder/6101685': 184
# Number of files in '/content/Eval4Deepseek-Coder/2782441': 317
# Number of files in '/content/Eval4Deepseek-Coder/59325776': 16
# Number of files in '/content/Eval4Deepseek-Coder/36790401': 5
# Number of files in '/content/Eval4Deepseek-Coder/107729923': 48
# Number of files in '/content/Eval4Deepseek-Coder/39472279': 89
# Number of files in '/content/Eval4Deepseek-Coder/7081691': 8
# Number of files in '/content/Eval4Deepseek-Coder/20087730': 2
# Number of files in '/content/Eval4Deepseek-Coder/15133047': 9
# Number of files in '/content/Eval4Deepseek-Coder/1362234': 15
# Number of files in '/content/Eval4Deepseek-Coder/2591797': 112
# Number of files in '/content/Eval4Deepseek-Coder/42987615': 35
# Number of files in '/content/Eval4Deepseek-Coder/44767534': 10
# Number of files in '/content/Eval4Deepseek-Coder/125645968': 42
# Number of files in '/content/Eval4Deepseek-Coder/53584459': 5
# Number of files in '/content/Eval4Deepseek-Coder/190294': 2
# Number of files in '/content/Eval4Deepseek-Coder/224018018': 99
# Number of files in '/content/Eval4Deepseek-Coder/38321655': 33
# Number of files in '/content/Eval4Deepseek-Coder/112582752': 1
# Number of files in '/content/Eval4Deepseek-Coder/2195909': 7
# Number of files in '/content/Eval4Deepseek-Coder/206366': 139
# Number of files in '/content/Eval4Deepseek-Coder/53036530': 10
# Number of files in '/content/Eval4Deepseek-Coder/148404302': 2
# Number of files in '/content/Eval4Deepseek-Coder/30175591': 1
# Number of files in '/content/Eval4Deepseek-Coder/36057260': 205
# Number of files in '/content/Eval4Deepseek-Coder/65371147': 17
# Number of files in '/content/Eval4Deepseek-Coder/3694329': 55
# Number of files in '/content/Eval4Deepseek-Coder/141299179': 50
# Number of files in '/content/Eval4Deepseek-Coder/1869419': 1
# Number of files in '/content/Eval4Deepseek-Coder/73266969': 113
# Number of files in '/content/Eval4Deepseek-Coder/6959258': 38
# Number of files in '/content/Eval4Deepseek-Coder/18406709': 91
# Number of files in '/content/Eval4Deepseek-Coder/201204692': 11
# Number of files in '/content/Eval4Deepseek-Coder/91066791': 2
# Number of files in '/content/Eval4Deepseek-Coder/94758234': 10
# Number of files in '/content/Eval4Deepseek-Coder/38882107': 62
# Number of files in '/content/Eval4Deepseek-Coder/68661482': 51
# Number of files in '/content/Eval4Deepseek-Coder/20555659': 3
# Number of files in '/content/Eval4Deepseek-Coder/2148480': 9
# Number of files in '/content/Eval4Deepseek-Coder/69880796': 69
# Number of files in '/content/Eval4Deepseek-Coder/1647022': 11
# Number of files in '/content/Eval4Deepseek-Coder/1441134': 485
# Number of files in '/content/Eval4Deepseek-Coder/107765383': 11
# Number of files in '/content/Eval4Deepseek-Coder/111418574': 12
# Number of files in '/content/Eval4Deepseek-Coder/55092090': 23
# Number of files in '/content/Eval4Deepseek-Coder/52231932': 1
# Number of files in '/content/Eval4Deepseek-Coder/5284824': 33
# Number of files in '/content/Eval4Deepseek-Coder/52804523': 287
# Number of files in '/content/Eval4Deepseek-Coder/1553784': 14
# Number of files in '/content/Eval4Deepseek-Coder/50648882': 1
# Number of files in '/content/Eval4Deepseek-Coder/95493108': 65
# Number of files in '/content/Eval4Deepseek-Coder/29740235': 51
# Number of files in '/content/Eval4Deepseek-Coder/15322863': 2
# Number of files in '/content/Eval4Deepseek-Coder/76684197': 105
# Number of files in '/content/Eval4Deepseek-Coder/176137170': 2
# Number of files in '/content/Eval4Deepseek-Coder/1164974': 38
# Number of files in '/content/Eval4Deepseek-Coder/1384929': 441
# Number of files in '/content/Eval4Deepseek-Coder/69984723': 1
# Number of files in '/content/Eval4Deepseek-Coder/2057739': 47
# Number of files in '/content/Eval4Deepseek-Coder/208977660': 74
# Number of files in '/content/Eval4Deepseek-Coder/147163148': 22
# Number of files in '/content/Eval4Deepseek-Coder/2079469': 105
# Number of files in '/content/Eval4Deepseek-Coder/1827687': 1
# Number of files in '/content/Eval4Deepseek-Coder/9463479': 124
# Number of files in '/content/Eval4Deepseek-Coder/18154401': 40
# Number of files in '/content/Eval4Deepseek-Coder/154520': 690
# Number of files in '/content/Eval4Deepseek-Coder/104892792': 1
# Number of files in '/content/Eval4Deepseek-Coder/55986996': 2
# Number of files in '/content/Eval4Deepseek-Coder/128030682': 62
# Number of files in '/content/Eval4Deepseek-Coder/2499961': 2
# Number of files in '/content/Eval4Deepseek-Coder/99087385': 27
# Number of files in '/content/Eval4Deepseek-Coder/38946154': 56
# Number of files in '/content/Eval4Deepseek-Coder/58591901': 74
# Number of files in '/content/Eval4Deepseek-Coder/121058856': 34
# Number of files in '/content/Eval4Deepseek-Coder/74091826': 2
# Number of files in '/content/Eval4Deepseek-Coder/132743903': 55
# Number of files in '/content/Eval4Deepseek-Coder/223421707': 1
# Number of files in '/content/Eval4Deepseek-Coder/92924762': 5
# Number of files in '/content/Eval4Deepseek-Coder/172115221': 4
# Number of files in '/content/Eval4Deepseek-Coder/58181287': 7
# Number of files in '/content/Eval4Deepseek-Coder/38680642': 6
# Number of files in '/content/Eval4Deepseek-Coder/67841511': 28
# Number of files in '/content/Eval4Deepseek-Coder/170642298': 4
# Number of files in '/content/Eval4Deepseek-Coder/132565379': 2
# Number of files in '/content/Eval4Deepseek-Coder/148223447': 70
# Number of files in '/content/Eval4Deepseek-Coder/124235951': 30
# Number of files in '/content/Eval4Deepseek-Coder/51952300': 4
# Number of files in '/content/Eval4Deepseek-Coder/42997858': 2
# Number of files in '/content/Eval4Deepseek-Coder/51292541': 340
# Number of files in '/content/Eval4Deepseek-Coder/65349739': 601
# Number of files in '/content/Eval4Deepseek-Coder/65498366': 5
# Number of files in '/content/Eval4Deepseek-Coder/15276235': 1
# Number of files in '/content/Eval4Deepseek-Coder/88651024': 7
# Number of files in '/content/Eval4Deepseek-Coder/15158202': 32
# Number of files in '/content/Eval4Deepseek-Coder/6271421': 410
# Number of files in '/content/Eval4Deepseek-Coder/331375': 4
# Number of files in '/content/Eval4Deepseek-Coder/7437073': 1513
# Number of files in '/content/Eval4Deepseek-Coder/55516736': 163
# Number of files in '/content/Eval4Deepseek-Coder/21861588': 12
# Number of files in '/content/Eval4Deepseek-Coder/143049657': 291
# Number of files in '/content/Eval4Deepseek-Coder/27812454': 1
# Number of files in '/content/Eval4Deepseek-Coder/34445488': 10
# Number of files in '/content/Eval4Deepseek-Coder/36371940': 3
# Number of files in '/content/Eval4Deepseek-Coder/64439009': 10
# Number of files in '/content/Eval4Deepseek-Coder/16660401': 9
# Number of files in '/content/Eval4Deepseek-Coder/26727938': 19
# Number of files in '/content/Eval4Deepseek-Coder/4584782': 2
# Number of files in '/content/Eval4Deepseek-Coder/52148204': 4
# Number of files in '/content/Eval4Deepseek-Coder/16058167': 23
# Number of files in '/content/Eval4Deepseek-Coder/169777604': 128
# Number of files in '/content/Eval4Deepseek-Coder/2136477': 11
# Number of files in '/content/Eval4Deepseek-Coder/68398311': 12
# Number of files in '/content/Eval4Deepseek-Coder/11830269': 124
# Number of files in '/content/Eval4Deepseek-Coder/178848687': 14
# Number of files in '/content/Eval4Deepseek-Coder/2988686': 34
# Number of files in '/content/Eval4Deepseek-Coder/33653374': 15
# Number of files in '/content/Eval4Deepseek-Coder/13923694': 1
# Number of files in '/content/Eval4Deepseek-Coder/29961332': 8
# Number of files in '/content/Eval4Deepseek-Coder/93971355': 4
# Number of files in '/content/Eval4Deepseek-Coder/256297959': 1
# Number of files in '/content/Eval4Deepseek-Coder/157912475': 5
# Number of files in '/content/Eval4Deepseek-Coder/18864134': 6
# Number of files in '/content/Eval4Deepseek-Coder/14422403': 49
# Number of files in '/content/Eval4Deepseek-Coder/135369996': 8
# Number of files in '/content/Eval4Deepseek-Coder/17188215': 86
# Number of files in '/content/Eval4Deepseek-Coder/82671449': 4
# Number of files in '/content/Eval4Deepseek-Coder/103674706': 2
# Number of files in '/content/Eval4Deepseek-Coder/59282155': 12
# Number of files in '/content/Eval4Deepseek-Coder/125078412': 3
# Number of files in '/content/Eval4Deepseek-Coder/42219129': 1
# Number of files in '/content/Eval4Deepseek-Coder/61282525': 12
# Number of files in '/content/Eval4Deepseek-Coder/859468': 23
# Number of files in '/content/Eval4Deepseek-Coder/205407': 73
# Number of files in '/content/Eval4Deepseek-Coder/2199115': 3
# Number of files in '/content/Eval4Deepseek-Coder/56678404': 37
# Number of files in '/content/Eval4Deepseek-Coder/104152070': 3
# Number of files in '/content/Eval4Deepseek-Coder/76228719': 11
# Number of files in '/content/Eval4Deepseek-Coder/172332638': 1
# Number of files in '/content/Eval4Deepseek-Coder/19006562': 70
# Number of files in '/content/Eval4Deepseek-Coder/13369644': 2
# Number of files in '/content/Eval4Deepseek-Coder/67593323': 7
# Number of files in '/content/Eval4Deepseek-Coder/50542309': 11
# Number of files in '/content/Eval4Deepseek-Coder/159332324': 104
# Number of files in '/content/Eval4Deepseek-Coder/80362083': 12
# Number of files in '/content/Eval4Deepseek-Coder/20256705': 7
# Number of files in '/content/Eval4Deepseek-Coder/59838788': 40
# Number of files in '/content/Eval4Deepseek-Coder/42369667': 305
# Number of files in '/content/Eval4Deepseek-Coder/243875832': 95
# Number of files in '/content/Eval4Deepseek-Coder/145737537': 15
# Number of files in '/content/Eval4Deepseek-Coder/141513537': 55
# Number of files in '/content/Eval4Deepseek-Coder/41505521': 95
# Number of files in '/content/Eval4Deepseek-Coder/41458986': 3
# Number of files in '/content/Eval4Deepseek-Coder/148370332': 9
# Number of files in '/content/Eval4Deepseek-Coder/121230866': 2
# Number of files in '/content/Eval4Deepseek-Coder/16453755': 199
# Number of files in '/content/Eval4Deepseek-Coder/31368772': 54
# Number of files in '/content/Eval4Deepseek-Coder/13501496': 77
# Number of files in '/content/Eval4Deepseek-Coder/148710969': 15
# Number of files in '/content/Eval4Deepseek-Coder/40132408': 1
# Number of files in '/content/Eval4Deepseek-Coder/62144290': 9
# Number of files in '/content/Eval4Deepseek-Coder/5126482': 49
# Number of files in '/content/Eval4Deepseek-Coder/97573661': 100
# Number of files in '/content/Eval4Deepseek-Coder/2406783': 19
# Number of files in '/content/Eval4Deepseek-Coder/10805187': 38
# Number of files in '/content/Eval4Deepseek-Coder/80504703': 3
# Number of files in '/content/Eval4Deepseek-Coder/97822421': 51
# Number of files in '/content/Eval4Deepseek-Coder/46065249': 42
# Number of files in '/content/Eval4Deepseek-Coder/136962671': 63
# Number of files in '/content/Eval4Deepseek-Coder/37489990': 21
# Number of files in '/content/Eval4Deepseek-Coder/6074181': 37
# Number of files in '/content/Eval4Deepseek-Coder/39727495': 102
# Number of files in '/content/Eval4Deepseek-Coder/100874896': 2
# Number of files in '/content/Eval4Deepseek-Coder/76684401': 206
# Number of files in '/content/Eval4Deepseek-Coder/1217322': 1
# Number of files in '/content/Eval4Deepseek-Coder/32025244': 37
# Number of files in '/content/Eval4Deepseek-Coder/45026577': 21
# Number of files in '/content/Eval4Deepseek-Coder/75863657': 2
# Number of files in '/content/Eval4Deepseek-Coder/2660111': 14
# Number of files in '/content/Eval4Deepseek-Coder/22417216': 1
# Number of files in '/content/Eval4Deepseek-Coder/216947263': 93
# Number of files in '/content/Eval4Deepseek-Coder/16456789': 1
# Number of files in '/content/Eval4Deepseek-Coder/32944108': 30
# Number of files in '/content/Eval4Deepseek-Coder/184477043': 4
# Number of files in '/content/Eval4Deepseek-Coder/123152853': 51
# Number of files in '/content/Eval4Deepseek-Coder/135131303': 1
# Number of files in '/content/Eval4Deepseek-Coder/5668425': 2
# Number of files in '/content/Eval4Deepseek-Coder/5279341': 41
# Number of files in '/content/Eval4Deepseek-Coder/181527588': 21
# Number of files in '/content/Eval4Deepseek-Coder/45100886': 2
# Number of files in '/content/Eval4Deepseek-Coder/32079125': 1
# Number of files in '/content/Eval4Deepseek-Coder/11683979': 45
# Number of files in '/content/Eval4Deepseek-Coder/143955196': 6
# Number of files in '/content/Eval4Deepseek-Coder/2610204': 27
# Number of files in '/content/Eval4Deepseek-Coder/72975288': 5
# Number of files in '/content/Eval4Deepseek-Coder/17799877': 132
# Number of files in '/content/Eval4Deepseek-Coder/155367310': 3
# Number of files in '/content/Eval4Deepseek-Coder/58310582': 18
# Number of files in '/content/Eval4Deepseek-Coder/920690': 15
# Number of files in '/content/Eval4Deepseek-Coder/31687471': 187
# Number of files in '/content/Eval4Deepseek-Coder/81384608': 371
# Number of files in '/content/Eval4Deepseek-Coder/26024464': 133
# Number of files in '/content/Eval4Deepseek-Coder/35449960': 2
# Number of files in '/content/Eval4Deepseek-Coder/173142957': 13
# Number of files in '/content/Eval4Deepseek-Coder/3720150': 7
# Number of files in '/content/Eval4Deepseek-Coder/23981303': 1
# Number of files in '/content/Eval4Deepseek-Coder/74562982': 259
# Number of files in '/content/Eval4Deepseek-Coder/2282376': 33
# Number of files in '/content/Eval4Deepseek-Coder/2601600': 22
# Number of files in '/content/Eval4Deepseek-Coder/41047231': 5
# Number of files in '/content/Eval4Deepseek-Coder/1401298': 58
# Number of files in '/content/Eval4Deepseek-Coder/8116816': 13
# Number of files in '/content/Eval4Deepseek-Coder/114859883': 141
# Number of files in '/content/Eval4Deepseek-Coder/5396680': 29
# Number of files in '/content/Eval4Deepseek-Coder/109365871': 1
# Number of files in '/content/Eval4Deepseek-Coder/31604621': 1
# Number of files in '/content/Eval4Deepseek-Coder/71135101': 12
# Number of files in '/content/Eval4Deepseek-Coder/532194': 7
# Number of files in '/content/Eval4Deepseek-Coder/85662445': 19
# Number of files in '/content/Eval4Deepseek-Coder/189742652': 3
# Number of files in '/content/Eval4Deepseek-Coder/36572602': 47
# Number of files in '/content/Eval4Deepseek-Coder/8003571': 343
# Number of files in '/content/Eval4Deepseek-Coder/1783086': 12
# Number of files in '/content/Eval4Deepseek-Coder/113231746': 10
# Number of files in '/content/Eval4Deepseek-Coder/30502761': 50
# Number of files in '/content/Eval4Deepseek-Coder/36551934': 7
# Number of files in '/content/Eval4Deepseek-Coder/80821553': 11
# Number of files in '/content/Eval4Deepseek-Coder/127820537': 21
# Number of files in '/content/Eval4Deepseek-Coder/30764444': 17
# Number of files in '/content/Eval4Deepseek-Coder/30895957': 8
# Number of files in '/content/Eval4Deepseek-Coder/41467872': 2
# Number of files in '/content/Eval4Deepseek-Coder/120436684': 3
# Number of files in '/content/Eval4Deepseek-Coder/143324400': 2
# Number of files in '/content/Eval4Deepseek-Coder/161296037': 1

# %% [markdown]
# ### Push to hugging Face

# %% [markdown]
# push to hugging face repo using legacy git method, this takes tons of time but immune to connection speed

# %%
repo.git_pull()

# %%
repo.push_to_hub(commit_message=f"{folder} uploaded")
# Out:
# To https://huggingface.co/datasets/CodexAI/Eval4Deepseek-Coder
#    0d7acc9..5f000b5  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/datasets/CodexAI/Eval4Deepseek-Coder
#    0d7acc9..5f000b5  main -> main
# 'https://huggingface.co/datasets/CodexAI/Eval4Deepseek-Coder/commit/5f000b52991f292fcfacc160ae8184aebf403af0'

# %% [markdown]
# Alternatively, use HFApi to push dataset to hugging face, this is faster then legacy git commands but requires consistant connection speed

# %%
from huggingface_hub import HfApi
api = HfApi()

# %%
os.chdir(output_path)

# %%
api.upload_folder(
  folder_path=output_path,
  repo_id=repo_id,
  repo_type="dataset",
)

# %% [markdown]
# ### Release the Space

# %%
shutil.rmtree(input_path)
shutil.rmtree(output_path)

# %%
os.remove('/content/logs.log')

# %%
from google.colab import drive
drive.flush_and_unmount()

# %% [markdown]
# ### All set!
